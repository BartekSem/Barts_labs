# %% [markdown]
# Lab date 29.01.2023

# %%
import pandas as pd

# %%
marketing_df = pd.read_csv("Data_Marketing_Customer_Analysis_Round3.csv")
marketing_df.head()
# Out:
#         region  customer_lifetime_value response  coverage education  \
# 0      central                     4809       no     basic   college
# 1  west region                     2228       no     basic   college
# 2         east                    14947       no     basic  bachelor
# 3   north west                    22332      yes  extended   college
# 4   north west                     9025       no   premium  bachelor
#
#   effective_to_date month employment_status gender  income  ...  \
# 0           2/18/11   feb          employed      m   48029  ...
# 1           1/18/11   jan        unemployed      f   92260  ...
# 2           2/10/11   feb          employed      m   22139  ...
# 3           1/11/11   jan          employed      m   49078  ...
# 4           1/17/11   jan     medical leave      f   23675  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                            52                         0                   9
# ...

# %%
marketing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10689 entries, 0 to 10688
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   region                         10689 non-null  object
#  1   customer_lifetime_value        10689 non-null  int64
#  2   response                       10689 non-null  object
#  3   coverage                       10689 non-null  object
#  4   education                      10689 non-null  object
#  5   effective_to_date              10689 non-null  object
#  6   month                          10689 non-null  object
#  7   employment_status              10689 non-null  object
#  8   gender                         10689 non-null  object
#  9   income                         10689 non-null  int64
#  10  location_code                  10689 non-null  object
#  11  marital_status                 10689 non-null  object
# ...

# %%
# EXAMINATING COLUMNS

# %%
unique_values_region = marketing_df['region'].unique()
unique_values_response = marketing_df['response'].unique()
unique_values_coverage = marketing_df['coverage'].unique()
unique_values_education = marketing_df['education'].unique()
unique_values_month = marketing_df['month'].unique()
unique_values_employment_status = marketing_df['employment_status'].unique()

# %%
print("Unique values in region:", unique_values_region)
print("Unique values in response:", unique_values_response)
print("Unique values in coverage:", unique_values_coverage)
print("Unique values in education:", unique_values_education)
print("Unique values in month:", unique_values_month)
print("Unique values in employment_status:", unique_values_employment_status)
# Out:
# Unique values in region: ['central' 'west region' 'east' 'north west']
# Unique values in response: ['no' 'yes']
# Unique values in coverage: ['basic' 'extended' 'premium']
# Unique values in education: ['college' 'bachelor' 'high school or below' 'doctor' 'master']
# Unique values in month: ['feb' 'jan']
# Unique values in employment_status: ['employed' 'unemployed' 'medical leave' 'disabled' 'retired']

# %%
# Checking for categorical values 
categorical_columns = marketing_df.select_dtypes(include='category').columns.tolist()
categorical_columns

# %%
# Convert 'Column2' to categorical
marketing_df['Column2'] = marketing_df['Column2'].astype('category')

# %% [markdown]
# Collected data can be affected by:
#
#     Outliers
#     Small/Big range
#     Skewness
#
# These problems can affect the predictive power of our model
#
# You will need to transform the data to:
#
#     Improve interpretability
#     Declutter graphs
#     Discover relationships between variables
#
#
# one approch is with MinMaxScaler

# %% [markdown]
# 1. apply min max on one variable (find a suitable variable in the set)

# %%
marketing_df = sns.load_dataset("number_of_open_complaints")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 marketing_df = sns.load_dataset("number_of_open_complaints")
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'number_of_open_complaints' is not one of the example datasets.

# %% [markdown]
# ------------------ LAB WORK ----------------------------------------------
#
# ---- GETTING FAMILAR WITH VAR AND APPLYING TRANSFORMERS -----

# %%
import seaborn as sns

# %%
tips_df = sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 tips_df = sns.load_dataset("number_of_open_complaints")
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'number_of_open_complaints' is not one of the example datasets.

# %%
tips_df ["total_bill"].hist()
# Out:
# <Axes: >

# %% [markdown]
# sklearn - library
#
# preprocessing - is a module
#
# MinMaxScaler - class (camlle case)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer

# %%
# APPLIYING MIN MAX SCALER 

scaler = MinMaxScaler()
scaler.fit(tips_df[["total_bill"]]) # defintes the range, finds min and max and creates a frame for the scale
scaler.transform(tips_df[["total_bill"]]) # applies formula to each value, amends data to scale
# Out:
# array([[0.29157939],
#        [0.1522832 ],
#        [0.3757855 ],
#        [0.43171345],
#        [0.45077503],
#        [0.46543779],
#        [0.11939673],
#        [0.49874319],
#        [0.25073314],
#        [0.24528697],
#        [0.15081693],
#        [0.67427734],
#        [0.25869292],
#        [0.32174277],
#        [0.24633431],
#        [0.38772518],
#        [0.15207373],
#        [0.27691663],
#        [0.29116045],
#        [0.36824466],
#        [0.31105991],
#        [0.36070381],
#        [0.2660243 ],
#        [0.761416  ],
#        [0.35085882],
#        [0.30875576],
#        [0.21575199],
#        [0.20150817],
#        [0.39023879],
#        [0.34729786],
#        [0.13573523],
#        [0.32006703],
#        [0.25115207],
#        [0.36908253],
#        [0.30812736],
#        [0.43967323],
#        [0.27733557],
#        [0.29032258],
#        [0.32718894],
#        [0.59069962],
#        [0.27167993],
#        [0.30142438],
#        [0.22769166],
# ...

# %%
tips_df["bill_minmax"] =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 scaler = sns.load_dataset("scaler")
#       2 scaler ["total_bill"].hist()
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/utils.py:587, in load_dataset(name, cache, data_home, **kws)
#     585 if not os.path.exists(cache_path):
#     586     if name not in get_dataset_names():
# --> 587         raise ValueError(f"'{name}' is not one of the example datasets.")
#     588     urlretrieve(url, cache_path)
#     589 full_path = cache_path
#
# ValueError: 'scaler' is not one of the example datasets.

# %%
# APPLIYING POWER SCALER

# %%
pt  = PowerTransformer(tips_df[["tip"]])

# %%
tips_df.tip.hist()
# right scue. we want to make the disctirbution bit more normal with the power transformer
# Out:
# <Axes: >

# %%
# APPLIYING Standard Scaler

scaler = StandardScaler()
scaler.fit_transform(tips_df[["total_bill"]])
# Out:
# array([[-3.14711305e-01],
#        [-1.06323531e+00],
#        [ 1.37779900e-01],
#        [ 4.38315103e-01],
#        [ 5.40744704e-01],
#        [ 6.19536705e-01],
#        [-1.23995452e+00],
#        [ 7.98507107e-01],
#        [-5.34203307e-01],
#        [-5.63468908e-01],
#        [-1.07111451e+00],
#        [ 1.74175992e+00],
#        [-4.91430507e-01],
#        [-1.52624903e-01],
#        [-5.57840908e-01],
#        [ 2.01939101e-01],
#        [-1.06436091e+00],
#        [-3.93503306e-01],
#        [-3.16962505e-01],
#        [ 9.72582994e-02],
#        [-2.10030504e-01],
#        [ 5.67366990e-02],
#        [-4.52034507e-01],
#        [ 2.21000952e+00],
#        [ 3.83349840e-03],
#        [-2.22412104e-01],
#        [-7.22178510e-01],
#        [-7.98719310e-01],
#        [ 2.15446301e-01],
#        [-1.53017018e-02],
#        [-1.15215771e+00],
#        [-1.61629703e-01],
#        [-5.31952107e-01],
#        [ 1.01760699e-01],
#        [-2.25788904e-01],
# ...

# %%
# ------- POTENCIAL VARIABLES FOR THE MIN MAX SCALER

# months_since_policy_inception
# customer_lifetime_value
# total_claim_amount
# number_of_open_complaints

# %% [markdown]
# ### Encoding categorical data

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
categorical_df = tips_df.select_dtypes(include = "category")
numerical_df = tips_df.select_dtypes(include = "number")

# %%
categorical_df
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
categorical_df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
numerical_df
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
nominals_df = pd.get_dummies(categorical_df[["sex", "smoker"]], dtype = int)
# Out:
#      sex_Male  sex_Female  smoker_Yes  smoker_No
# 0           0           1           0          1
# 1           1           0           0          1
# 2           1           0           0          1
# 3           1           0           0          1
# 4           0           1           0          1
# ..        ...         ...         ...        ...
# 239         1           0           0          1
# 240         0           1           1          0
# 241         1           0           1          0
# 242         1           0           0          1
# 243         0           1           0          1
#
# [244 rows x 4 columns]

# %%
categorical_df
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
# assign numbers to values. we can use for the lab either this or transformer 
categorical_df["time"].map({"Dinner":1, "Launch": 0})
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 239    1.0
# 240    1.0
# 241    1.0
# 242    1.0
# 243    1.0
# Name: time, Length: 244, dtype: float64

# %%
from sklearn.preprocessing import OrdinalEncoder
