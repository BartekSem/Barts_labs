# %%
pip install meteostat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)

# Create Point for Vancouver, BC
vancouver = Point(49.2497, -123.1193, 70)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)

# Create Point for Munich, Germany
munich = Point(48.1351, 11.5820, 520)

# Get daily data for Munich in 2018
data = Daily(munich, start, end)
data = data.fetch()

# Plot line chart including average, minimum, and maximum temperature
data.plot(y=['temperature_2m_max', 'temperature_2m_min', 'temperature_2m'])
plt.title("Daily Temperature in Munich (2018)")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.legend(["Max Temperature", "Min Temperature", "Avg Temperature"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 18
#      15 data = data.fetch()
#      17 # Plot line chart including average, minimum, and maximum temperature
# ---> 18 data.plot(y=['temperature_2m_max', 'temperature_2m_min', 'temperature_2m'])
#      19 plt.title("Daily Temperature in Munich (2018)")
#      20 plt.xlabel("Date")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:961, in PlotAccessor.__call__(self, *args, **kwargs)
#     958             pass
#     960 # don't overwrite
# --> 961 data = data[y].copy()
#     963 if isinstance(data, ABCSeries):
#     964     label_name = label_kw or y
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# ...
